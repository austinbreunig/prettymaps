# %%
import prettymaps
from matplotlib.font_manager import FontProperties

# %%
font_fname = r'C:\GitHub\prettymaps\assets\PermanentMarker-Regular.ttf'

# %%
coords = '40.00712844069614, -105.27054998582835'

# %%
plot = prettymaps.plot(
    coords,
    circle = False,
    radius = 770,
    layers = {
        "green": {
            "tags": {
                "landuse": ["grass", 'recreation_ground'],
                "natural": ["grassland"],
                "leisure": ['pitch', 'garden', 'fitness_centre', 'park']
            }
        },
        "water": {
            "tags": {
                "natural": ["water", "bay"],
                
            }
        },
        "stream": {
            "tags": {
                "waterway": 'stream'
            }
        },
        "parking": {
            "tags": {
                "amenity": ["parking", "bicycle_parking", "motorcycle_parking"],
                "highway": "pedestrian",
                "man_made": "pier"
            }
        },
        "streets": {
            "width": {
                "motorway": 5,
                "trunk": 5,
                "primary": 4.5,
                "secondary": 2,
                "tertiary": 3.5,
                "residential": 2,
                'service': 0.5,
                'secondary_link': 2, 
                'cycleway': 2, 
                'track': 1, 
                'footway': 1,  
                'steps': 1,
                'pedestrian': 1, 
                'living_street': 1
            }
        },
        "trails": {
            "tags": {
                "highway": "path"
                }
            },
        "building": {
            "tags": {"building": True,
                     "building": ["university",
                                  "library",
                                  "house",
                                  "dormitory",
                                  "stadium",
                                  "church",
                                  "commercial",
                                  "roof", 
                                  "service",
                                  "shed",
                                  "yes",
                                  "office",
                                  'public'
                                  ],
                    "leisure": "sports_centre",
                    "amenity": ["theatre", "community_centre"]
                    },
        },
    },
    style = {
        "background": {
            "fc": "#F2F4CB",
            "ec": "#dadbc1",
            "hatch": "ooo...",
        },
        "perimeter": {
            "fc": "#F2F4CB",
            "ec": "#dadbc1",
            "lw": 0,
            "hatch": "ooo...",
        },
        
        "water": {
            "fc": "#a1e3ff",
            "ec": "#2F3737",
            "hatch": "ooo...",
            "hatch_c": "#85c9e6",
            "lw": 1,
        },
        "parking": {
            "fc": "#F2F4CB",
            "ec": "#2F3737",
            "lw": 0.5,
        },
        "streets": {
            "fc": "#2F3737",
            "ec": "#475657",
            "alpha": 1,
            "lw": 0,
        },
        "building": {
            "palette": [
                '#feb302', # yellow
                '#392009', # brown
                '#312723'  # grey/black
            ],
            "ec": "#2F3737",
            "lw": 0.5,
        },
        "green": {
            "fc": "#A3C486",
            "ec": "#2F3737",
            "lw": 1,
            "alpha": 0.5
        },
        "trails": {
            "fc": "#B0920D",
            "ec": "#8E7814",
            "lw": 1,
            "linestyle": "dotted"
        },
        "stream": {
            "ec": "#a1e3ff",
            "lw": 1
        }
    }
)

# Change background color
plot.fig.patch.set_facecolor('#F2F4CB')
# Add title
plot.ax.set_title(
    'University of Colorado \n Boulder',
    fontproperties = FontProperties(
        fname = font_fname,
        size = 40
    )
)
# Out:
# Text(0.5, 1.0, 'University of Colorado \n Boulder')
