# %%
import prettymaps
import matplotlib.pyplot as plt
# %matplotlib inline
import geopandas as gpd

# %%
#plot = prettymaps.plot('36.99210845093066, -122.06095605720316', preset='macao', radius=1000)

# %%
from matplotlib.font_manager import FontProperties

# %% [markdown]
# center coordinates
# 36.99456347183961, -122.06106227515143
# 36.99210845093066, -122.06095605720316 # current default
# 36.99277743327781, -122.06026254832031
#
# """
#         "green": {
#             "tags": {
#                 "landuse": "grass",
#                 "natural": ["grassland", "wood"],
#                 "leisure": ["park", "nature_reserve"]
#             }
#         },
#         """
#
#         "green": {
#             "fc": "#A3C486",
#             "ec": "#2F3737",
#             "lw": 1,
#             "alpha": 0.5
#         },

# %%
plot = prettymaps.plot(
    '36.993683950002776, -122.05882597328052',
    circle = True,
    radius = 1100,
    layers = {
        "green": {
            "tags": {
                "landuse": "grass",
                "natural": ["grassland", "wood"],
                "leisure": ["park", "nature_reserve"]
            }
        },
        "water": {
            "tags": {
                "natural": ["water", "bay"]
            }
        },
        "parking": {
            "tags": {
                "amenity": "parking",
                "highway": "pedestrian",
                "man_made": "pier"
            }
        },
        "streets": {
            "width": {
                "motorway": 5,
                "trunk": 5,
                "primary": 4.5,
                "secondary": 4,
                "tertiary": 3.5,
                "residential": 3,
                'service': 2.5,
                'secondary_link': 3, 
                'cycleway': 2, 
                'track': 1, 
                'footway': 1,  
                'steps': 1,
                'pedestrian': 1, 
                'living_street': 1
            }
        },
        "building": {
            "tags": {"building": True,
                     "building": ["university",
                                  "library",
                                  "house",
                                  "dormitory",
                                  "industrial",
                                  "roof",
                                  "trailer",
                                  "residential",
                                  "apartments",
                                  "service",
                                  "shed",
                                  "yes",
                                  "office",
                                  ]},
        },
    },
    style = {
        "background": {
            "fc": "#F2F4CB",
            "ec": "#dadbc1",
            "hatch": "ooo...",
        },
        "perimeter": {
            "fc": "#F2F4CB",
            "ec": "#dadbc1",
            "lw": 0,
            "hatch": "ooo...",
        },
        
        "water": {
            "fc": "#a1e3ff",
            "ec": "#2F3737",
            "hatch": "ooo...",
            "hatch_c": "#85c9e6",
            "lw": 1,
        },
        "parking": {
            "fc": "#F2F4CB",
            "ec": "#2F3737",
            "lw": 1,
        },
        "streets": {
            "fc": "#2F3737",
            "ec": "#475657",
            "alpha": 1,
            "lw": 0,
        },
        "building": {
            "palette": [
                '#E5B517', # orange"#FFC857"
                '#455B64', # red"#E9724C"
                '#A06B18'  # dark red # "#C5283D"
            ],
            "ec": "#2F3737",
            "lw": 0.5,
        },
        "green": {
            "fc": "#A3C486",
            "ec": "#2F3737",
            "lw": 1,
            "alpha": 0.5
        }
    }
)

# Change background color
plot.fig.patch.set_facecolor('#F2F4CB')
# Add title
plot.ax.set_title(
    'University of California \n Santa Cruz',
    fontproperties = FontProperties(
        fname = 'PermanentMarker-Regular.ttf',
        size = 50
    )
)
# Out:
# Text(0.5, 1.0, 'University of California \n Santa Cruz')
# findfont: Font family 'Ubuntu Mono' not found.
# findfont: Font family 'Ubuntu Mono' not found.
# findfont: Font family 'Ubuntu Mono' not found.
# findfont: Font family 'Ubuntu Mono' not found.
# findfont: Font family 'Ubuntu Mono' not found.
# findfont: Font family 'Ubuntu Mono' not found.
# findfont: Font family 'Ubuntu Mono' not found.
# findfont: Font family 'Ubuntu Mono' not found.
# findfont: Font family 'Ubuntu Mono' not found.
# findfont: Font family 'Ubuntu Mono' not found.
